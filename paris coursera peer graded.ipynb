# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bamigboye Temilade Paris**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I want to be able to you data to be able to solve problems in the health care sector*

# %% [markdown]
# <h3>My code in the cell below is going to Print out "My name is Temilade Paris" has its output</h3>

# %%
print("My name is Temilade Paris")
# Out:
# My name is Temilade Paris

# %% [markdown]
# <ul>
# <li> Temi </li>
# <li> Paris </li>
# <li> benedict </li>
# </ul>
#
# <ol>
# <li> potato </li>
# <li> jean </li>
# <li> basil </li>
# <ol>
#
#
#
#
#
# <hr>
